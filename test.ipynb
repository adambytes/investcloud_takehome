# %%
# # testing to see matrix shape
# url = "https://recruitment-test.investcloud.com/api/numbers"
# data = requests.get(f"{url}/init/10")
# print(data.json())
# data = requests.get(f"{url}/A/row/0")
# print(data.json())

# %%
# def parse_list(data: bytes) -> list[int]:
#     start = data.find(b"'Value': [") + len(b"'Value': [") + 1
#     # start = data.find(b"Value") + 1
#     end = data.find(b"]", start)
#     value_b = data[start:end]
#     return list(map(int, value_b.split(b",")))


# async with aiohttp.ClientSession() as session:
#     async with session.get(f"{url}/A/row/0") as resp:
#         data = await resp.read()
#         print(data)
#         custom = parse_list(data)
#         print(custom)
#     await session.close()

# %%
import numpy as np


def test_hashing(array):
    transpose = np.transpose(array)
    flattened = "".join([str(i) for i in transpose.flatten()])
    print(flattened)
    hash = hashlib.md5(flattened.encode()).hexdigest()
    print(hash)
rows = api.rows
cols = api.cols
result = cp.matmul(rows, cols)
print(test_hashing(result))

# %%
import requests

url = "https://recruitment-test.investcloud.com/api/numbers/A/row/0"

data = requests.get(url).json()

print(data["Value"])
# Out:
# [826, 919, 167, -739, -966, -304, 636, 992, 436, -521, -999, -558, 396, 986, 670, -262, -953, -768, 123, 901, 850, 17, -831, -916, -158, 745, 963, 296, -643, -991, -428, 529, 999, 551, -404, -988, -663, 270, 956, 762, -132, -905, -846, -8, 836, 912, 149, -751, -961, -287, 650, 990, 420, -536, -999, -543, 412, 989, 656, -279, -958, -756, 141, 909, 841, 0, -841, -909, -141, 756, 958, 279, -657, -989, -412, 544, 999, 536, -420, -990, -650, 287, 961, 750, -149, -912, -836, 8, 846, 905, 132, -762, -956, -270, 663, 988, 403, -551, -999, -529, 428, 991, 643, -296, -963, -745, 158, 916, 831, -17, -850, -901, -123, 768, 953, 262, -670, -986, -395, 558, 999, 521, -436, -992, -636, 304, 966, 739, -167, -920, -826, 26, 855, 897, 114, -773, -951, -253, 676, 985, 387, -566, -999, -513, 444, 993, 629, -313, -968, -733, 176, 923, 821, -35, -860, -893, -105, 779, 948, 245, -683, -983, -379, 573, 999, 506, -452, -994, -622, 321, 970, 727, -184, -926, -816, 44, 864, 889, 97, -785, -945, -236, 689, 981,
# ...
